# %% [markdown]
# # Explanatory data analysis  & data presentation (Movies Dataset)

# %% [markdown]
# data import and first inspection

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
pd.options.display.max_columns = 30
pd.options.display.float_format='{:.2f}'.format

# %%
df = pd.read_csv("movies_complete.csv",parse_dates=['release_date'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.10/site-packages/IPython/core/formatters.py:711, in PlainTextFormatter.__call__(self, obj)
#     704 stream = StringIO()
#     705 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     706     self.max_width, self.newline,
#     707     max_seq_length=self.max_seq_length,
#     708     singleton_pprinters=self.singleton_printers,
#     709     type_pprinters=self.type_printers,
#     710     deferred_pprinters=self.deferred_printers)
# --> 711 printer.pretty(obj)
#     712 printer.flush()
#     713 return stream.getvalue()
#
# File /opt/anaconda3/lib/python3.10/site-packages/IPython/lib/pretty.py:411, in RepresentationPrinter.pretty(self, obj)
#     408                         return meth(obj, self, cycle)
#     409                 if cls is not object \
#     410                         and callable(cls.__dict__.get('__repr__')):
# --> 411                     return _repr_pprint(obj, self, cycle)
#     413     return _default_pprint(obj, self, cycle)
#     414 finally:
#
# File /opt/anaconda3/lib/python3.10/site-packages/IPython/lib/pretty.py:779, in _repr_pprint(obj, p, cycle)
#     777 """A pprint that just redirects to the normal repr function."""
#     778 # Find newlines and replace them with p.break_()
# --> 779 output = repr(obj)
#     780 lines = output.splitlines()
#     781 with p.group():
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1606, in FloatArrayFormatter._format_strings(self)
#    1605 def _format_strings(self) -> list[str]:
# -> 1606     return list(self.get_result_as_array())
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1523, in FloatArrayFormatter.get_result_as_array(self)
#    1520     return formatted
#    1522 if self.formatter is not None:
# -> 1523     return format_with_na_rep(self.values, self.formatter, self.na_rep)
#    1525 if self.fixed_width:
#    1526     threshold = get_option("display.chop_threshold")
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1515, in FloatArrayFormatter.get_result_as_array.<locals>.format_with_na_rep(values, formatter, na_rep)
#    1512 def format_with_na_rep(values: ArrayLike, formatter: Callable, na_rep: str):
#    1513     mask = isna(values)
#    1514     formatted = np.array(
# -> 1515         [
#    1516             formatter(val) if not m else na_rep
#    1517             for val, m in zip(values.ravel(), mask.ravel())
#    1518         ]
#    1519     ).reshape(values.shape)
#    1520     return formatted
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1516, in <listcomp>(.0)
#    1512 def format_with_na_rep(values: ArrayLike, formatter: Callable, na_rep: str):
#    1513     mask = isna(values)
#    1514     formatted = np.array(
#    1515         [
# -> 1516             formatter(val) if not m else na_rep
#    1517             for val, m in zip(values.ravel(), mask.ravel())
#    1518         ]
#    1519     ).reshape(values.shape)
#    1520     return formatted
#
# ValueError: Single '}' encountered in format string
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.10/site-packages/IPython/core/formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:1106, in DataFrame._repr_html_(self)
#    1084     show_dimensions = get_option("display.show_dimensions")
#    1086     formatter = fmt.DataFrameFormatter(
#    1087         self,
#    1088         columns=None,
#    (...)
#    1104         decimal=".",
#    1105     )
# -> 1106     return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#    1107 else:
#    1108     return None
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1110, in DataFrameRenderer.to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1101 Klass = NotebookFormatter if notebook else HTMLFormatter
#    1103 html_formatter = Klass(
#    1104     self.fmt,
#    1105     classes=classes,
#    (...)
#    1108     render_links=render_links,
#    1109 )
# -> 1110 string = html_formatter.to_string()
#    1111 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:77, in HTMLFormatter.to_string(self)
#      76 def to_string(self) -> str:
# ---> 77     lines = self.render()
#      78     if any(isinstance(x, str) for x in lines):
#      79         lines = [str(x) for x in lines]
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:632, in NotebookFormatter.render(self)
#     630 self.write("<div>")
#     631 self.write_style()
# --> 632 super().render()
#     633 self.write("</div>")
#     634 return self.elements
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:83, in HTMLFormatter.render(self)
#      82 def render(self) -> list[str]:
# ---> 83     self._write_table()
#      85     if self.should_show_dimensions:
#      86         by = chr(215)  # ×
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:258, in HTMLFormatter._write_table(self, indent)
#     255 if self.fmt.header or self.show_row_idx_names:
#     256     self._write_header(indent + self.indent_delta)
# --> 258 self._write_body(indent + self.indent_delta)
#     260 self.write("</table>", indent)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:406, in HTMLFormatter._write_body(self, indent)
#     404 def _write_body(self, indent: int) -> None:
#     405     self.write("<tbody>", indent)
# --> 406     fmt_values = self._get_formatted_values()
#     408     # write values
#     409     if self.fmt.index and isinstance(self.frame.index, MultiIndex):
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:596, in NotebookFormatter._get_formatted_values(self)
#     595 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 596     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:596, in <dictcomp>(.0)
#     595 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 596     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1606, in FloatArrayFormatter._format_strings(self)
#    1605 def _format_strings(self) -> list[str]:
# -> 1606     return list(self.get_result_as_array())
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1523, in FloatArrayFormatter.get_result_as_array(self)
#    1520     return formatted
#    1522 if self.formatter is not None:
# -> 1523     return format_with_na_rep(self.values, self.formatter, self.na_rep)
#    1525 if self.fixed_width:
#    1526     threshold = get_option("display.chop_threshold")
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1515, in FloatArrayFormatter.get_result_as_array.<locals>.format_with_na_rep(values, formatter, na_rep)
#    1512 def format_with_na_rep(values: ArrayLike, formatter: Callable, na_rep: str):
#    1513     mask = isna(values)
#    1514     formatted = np.array(
# -> 1515         [
#    1516             formatter(val) if not m else na_rep
#    1517             for val, m in zip(values.ravel(), mask.ravel())
#    1518         ]
#    1519     ).reshape(values.shape)
#    1520     return formatted
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1516, in <listcomp>(.0)
#    1512 def format_with_na_rep(values: ArrayLike, formatter: Callable, na_rep: str):
#    1513     mask = isna(values)
#    1514     formatted = np.array(
#    1515         [
# -> 1516             formatter(val) if not m else na_rep
#    1517             for val, m in zip(values.ravel(), mask.ravel())
#    1518         ]
#    1519     ).reshape(values.shape)
#    1520     return formatted
#
# ValueError: Single '}' encountered in format string

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
#  14  runtime                43179 non-null  float64
#  15  overview               43740 non-null  object
#  16  spoken_languages       41094 non-null  object
#  17  poster_path            44467 non-null  object
#  18  cast                   42502 non-null  object
#  19  cast_size              44691 non-null  int64
#  20  crew_size              44691 non-null  int64
#  21  director               43960 non-null  object
# dtypes: datetime64[ns](1), float64(6), int64(3), object(12)
# memory usage: 7.5+ MB

# %% [markdown]
# # features
#
#
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
df.genres[1]
# Out:
# 'Adventure|Fantasy|Family'

# %%
df.cast[1]
# Out:
# 'Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyrus Thiedeke|Gary Joseph Thorup|Leonard Zola|Lloyd Berry|Malcolm Stewart|Annabel Kershaw|Darryl Henriques|Robyn Driscoll|Peter Bryant|Sarah Gilson|Florica Vlad|June Lion|Brenda Lockmuller'

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.10/site-packages/IPython/core/formatters.py:711, in PlainTextFormatter.__call__(self, obj)
#     704 stream = StringIO()
#     705 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     706     self.max_width, self.newline,
#     707     max_seq_length=self.max_seq_length,
#     708     singleton_pprinters=self.singleton_printers,
#     709     type_pprinters=self.type_printers,
#     710     deferred_pprinters=self.deferred_printers)
# --> 711 printer.pretty(obj)
#     712 printer.flush()
#     713 return stream.getvalue()
#
# File /opt/anaconda3/lib/python3.10/site-packages/IPython/lib/pretty.py:411, in RepresentationPrinter.pretty(self, obj)
#     408                         return meth(obj, self, cycle)
#     409                 if cls is not object \
#     410                         and callable(cls.__dict__.get('__repr__')):
# --> 411                     return _repr_pprint(obj, self, cycle)
#     413     return _default_pprint(obj, self, cycle)
#     414 finally:
#
# File /opt/anaconda3/lib/python3.10/site-packages/IPython/lib/pretty.py:779, in _repr_pprint(obj, p, cycle)
#     777 """A pprint that just redirects to the normal repr function."""
#     778 # Find newlines and replace them with p.break_()
# --> 779 output = repr(obj)
#     780 lines = output.splitlines()
#     781 with p.group():
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:1064, in DataFrame.__repr__(self)
#    1061     return buf.getvalue()
#    1063 repr_params = fmt.get_dataframe_repr_params()
# -> 1064 return self.to_string(**repr_params)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:1245, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1226 with option_context("display.max_colwidth", max_colwidth):
#    1227     formatter = fmt.DataFrameFormatter(
#    1228         self,
#    1229         columns=columns,
#    (...)
#    1243         decimal=decimal,
#    1244     )
# -> 1245     return fmt.DataFrameRenderer(formatter).to_string(
#    1246         buf=buf,
#    1247         encoding=encoding,
#    1248         line_width=line_width,
#    1249     )
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1136, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1133 from pandas.io.formats.string import StringFormatter
#    1135 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136 string = string_formatter.to_string()
#    1137 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/string.py:30, in StringFormatter.to_string(self)
#      29 def to_string(self) -> str:
# ---> 30     text = self._get_string_representation()
#      31     if self.fmt.should_show_dimensions:
#      32         text = "".join([text, self.fmt.dimensions_info])
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/string.py:45, in StringFormatter._get_string_representation(self)
#      42 if self.fmt.frame.empty:
#      43     return self._empty_info_line
# ---> 45 strcols = self._get_strcols()
#      47 if self.line_width is None:
#      48     # no need to wrap around just print the whole frame
#      49     return self.adj.adjoin(1, *strcols)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/string.py:36, in StringFormatter._get_strcols(self)
#      35 def _get_strcols(self) -> list[list[str]]:
# ---> 36     strcols = self.fmt.get_strcols()
#      37     if self.fmt.is_truncated:
#      38         strcols = self._insert_dot_separators(strcols)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:617, in DataFrameFormatter.get_strcols(self)
#     613 def get_strcols(self) -> list[list[str]]:
#     614     """
#     615     Render a DataFrame to a list of columns (as lists of strings).
#     616     """
# --> 617     strcols = self._get_strcols_without_index()
#     619     if self.index:
#     620         str_index = self._get_formatted_index(self.tr_frame)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:883, in DataFrameFormatter._get_strcols_without_index(self)
#     879 cheader = str_columns[i]
#     880 header_colwidth = max(
#     881     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882 )
# --> 883 fmt_values = self.format_col(i)
#     884 fmt_values = _make_fixed_width(
#     885     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886 )
#     888 max_len = max(max(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1606, in FloatArrayFormatter._format_strings(self)
#    1605 def _format_strings(self) -> list[str]:
# -> 1606     return list(self.get_result_as_array())
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1523, in FloatArrayFormatter.get_result_as_array(self)
#    1520     return formatted
#    1522 if self.formatter is not None:
# -> 1523     return format_with_na_rep(self.values, self.formatter, self.na_rep)
#    1525 if self.fixed_width:
#    1526     threshold = get_option("display.chop_threshold")
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1515, in FloatArrayFormatter.get_result_as_array.<locals>.format_with_na_rep(values, formatter, na_rep)
#    1512 def format_with_na_rep(values: ArrayLike, formatter: Callable, na_rep: str):
#    1513     mask = isna(values)
#    1514     formatted = np.array(
# -> 1515         [
#    1516             formatter(val) if not m else na_rep
#    1517             for val, m in zip(values.ravel(), mask.ravel())
#    1518         ]
#    1519     ).reshape(values.shape)
#    1520     return formatted
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1516, in <listcomp>(.0)
#    1512 def format_with_na_rep(values: ArrayLike, formatter: Callable, na_rep: str):
#    1513     mask = isna(values)
#    1514     formatted = np.array(
#    1515         [
# -> 1516             formatter(val) if not m else na_rep
#    1517             for val, m in zip(values.ravel(), mask.ravel())
#    1518         ]
#    1519     ).reshape(values.shape)
#    1520     return formatted
#
# ValueError: Single '}' encountered in format string
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.10/site-packages/IPython/core/formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:1106, in DataFrame._repr_html_(self)
#    1084     show_dimensions = get_option("display.show_dimensions")
#    1086     formatter = fmt.DataFrameFormatter(
#    1087         self,
#    1088         columns=None,
#    (...)
#    1104         decimal=".",
#    1105     )
# -> 1106     return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#    1107 else:
#    1108     return None
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1110, in DataFrameRenderer.to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1101 Klass = NotebookFormatter if notebook else HTMLFormatter
#    1103 html_formatter = Klass(
#    1104     self.fmt,
#    1105     classes=classes,
#    (...)
#    1108     render_links=render_links,
#    1109 )
# -> 1110 string = html_formatter.to_string()
#    1111 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:77, in HTMLFormatter.to_string(self)
#      76 def to_string(self) -> str:
# ---> 77     lines = self.render()
#      78     if any(isinstance(x, str) for x in lines):
#      79         lines = [str(x) for x in lines]
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:632, in NotebookFormatter.render(self)
#     630 self.write("<div>")
#     631 self.write_style()
# --> 632 super().render()
#     633 self.write("</div>")
#     634 return self.elements
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:83, in HTMLFormatter.render(self)
#      82 def render(self) -> list[str]:
# ---> 83     self._write_table()
#      85     if self.should_show_dimensions:
#      86         by = chr(215)  # ×
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:258, in HTMLFormatter._write_table(self, indent)
#     255 if self.fmt.header or self.show_row_idx_names:
#     256     self._write_header(indent + self.indent_delta)
# --> 258 self._write_body(indent + self.indent_delta)
#     260 self.write("</table>", indent)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:406, in HTMLFormatter._write_body(self, indent)
#     404 def _write_body(self, indent: int) -> None:
#     405     self.write("<tbody>", indent)
# --> 406     fmt_values = self._get_formatted_values()
#     408     # write values
#     409     if self.fmt.index and isinstance(self.frame.index, MultiIndex):
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:596, in NotebookFormatter._get_formatted_values(self)
#     595 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 596     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/html.py:596, in <dictcomp>(.0)
#     595 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 596     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:897, in DataFrameFormatter.format_col(self, i)
#     895 frame = self.tr_frame
#     896 formatter = self._get_formatter(i)
# --> 897 return format_array(
#     898     frame.iloc[:, i]._values,
#     899     formatter,
#     900     float_format=self.float_format,
#     901     na_rep=self.na_rep,
#     902     space=self.col_space.get(frame.columns[i]),
#     903     decimal=self.decimal,
#     904     leading_space=self.index,
#     905 )
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1606, in FloatArrayFormatter._format_strings(self)
#    1605 def _format_strings(self) -> list[str]:
# -> 1606     return list(self.get_result_as_array())
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1523, in FloatArrayFormatter.get_result_as_array(self)
#    1520     return formatted
#    1522 if self.formatter is not None:
# -> 1523     return format_with_na_rep(self.values, self.formatter, self.na_rep)
#    1525 if self.fixed_width:
#    1526     threshold = get_option("display.chop_threshold")
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1515, in FloatArrayFormatter.get_result_as_array.<locals>.format_with_na_rep(values, formatter, na_rep)
#    1512 def format_with_na_rep(values: ArrayLike, formatter: Callable, na_rep: str):
#    1513     mask = isna(values)
#    1514     formatted = np.array(
# -> 1515         [
#    1516             formatter(val) if not m else na_rep
#    1517             for val, m in zip(values.ravel(), mask.ravel())
#    1518         ]
#    1519     ).reshape(values.shape)
#    1520     return formatted
#
# File /opt/anaconda3/lib/python3.10/site-packages/pandas/io/formats/format.py:1516, in <listcomp>(.0)
#    1512 def format_with_na_rep(values: ArrayLike, formatter: Callable, na_rep: str):
#    1513     mask = isna(values)
#    1514     formatted = np.array(
#    1515         [
# -> 1516             formatter(val) if not m else na_rep
#    1517             for val, m in zip(values.ravel(), mask.ravel())
#    1518         ]
#    1519     ).reshape(values.shape)
#    1520     return formatted
#
# ValueError: Single '}' encountered in format string
